# %%
import numpy as np
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,np.nan,99,87,np.nan,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female'],
                'Email':['priyang@gmail.com','aadhya@gmail.com',
                        'krisha@gmail.com','vedant@yahoo.com','parshv@hotmail.com',
                         'mittal@yahoo.com','archana@yahoo.com']
               }
df=pd.DataFrame(dict1)
df
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df.head(3)
# Out:
#       Name  Marks  Gender              Email
# 0  Priyang   98.0    Male  priyang@gmail.com
# 1   Aadhya    NaN  Female   aadhya@gmail.com
# 2   Krisha   99.0  Female   krisha@gmail.com

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender               Email
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df.head(-2)
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com

# %%
df.tail(-3)
# Out:
#       Name  Marks  Gender               Email
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df.shape
# Out:
# (7, 4)

# %%
df
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df['Marks'].shape
# Out:
# (7,)

# %%
df['Marks']
# Out:
# 0    98.0
# 1     NaN
# 2    99.0
# 3    87.0
# 4     NaN
# 5    83.0
# 6    99.0
# Name: Marks, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   5 non-null      float64
#  2   Gender  7 non-null      object
#  3   Email   7 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
df.describe()
# Out:
#            Marks
# count   5.000000
# mean   93.200000
# std     7.628892
# min    83.000000
# 25%    87.000000
# 50%    98.000000
# 75%    99.000000
# max    99.000000

# %%
df.isnull()
# Out:
#     Name  Marks  Gender  Email
# 0  False  False   False  False
# 1  False   True   False  False
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False   True   False  False
# 5  False  False   False  False
# 6  False  False   False  False

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     2
# Gender    0
# Email     0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#            Name      Marks  Gender              Email
# count         7   5.000000       7                  7
# unique        7        NaN       2                  7
# top     Priyang        NaN  Female  priyang@gmail.com
# freq          1        NaN       4                  1
# mean        NaN  93.200000     NaN                NaN
# std         NaN   7.628892     NaN                NaN
# min         NaN  83.000000     NaN                NaN
# 25%         NaN  87.000000     NaN                NaN
# 50%         NaN  98.000000     NaN                NaN
# 75%         NaN  99.000000     NaN                NaN
# max         NaN  99.000000     NaN                NaN

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'Email'], dtype='object')

# %%
df['Marks'].unique()
# Out:
# array([98., nan, 99., 87., 83.])

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender']
# Out:
# 0      Male
# 1    Female
# 2    Female
# 3      Male
# 4      Male
# 5    Female
# 6    Female
# Name: Gender, dtype: object

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %%
df
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df.dropna()
# Out:
#       Name  Marks  Gender              Email
# 0  Priyang   98.0    Male  priyang@gmail.com
# 2   Krisha   99.0  Female   krisha@gmail.com
# 3   Vedant   87.0    Male   vedant@yahoo.com
# 5   Mittal   83.0  Female   mittal@yahoo.com
# 6  Archana   99.0  Female  archana@yahoo.com

# %%
df.dropna(how='any')
# Out:
#       Name  Marks  Gender              Email
# 0  Priyang   98.0    Male  priyang@gmail.com
# 2   Krisha   99.0  Female   krisha@gmail.com
# 3   Vedant   87.0    Male   vedant@yahoo.com
# 5   Mittal   83.0  Female   mittal@yahoo.com
# 6  Archana   99.0  Female  archana@yahoo.com

# %%
df.dropna(how='all')
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    NaN  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    NaN    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df.fillna(0)
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya    0.0  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv    0.0    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df['Marks'] = df['Marks'].fillna(df['Marks'].mean())

# %%
df
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya   93.2  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv   93.2    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df \
[(df['Marks'] >= 80) & (df['Marks'] <= 90)]
# Out:
#      Name  Marks  Gender             Email
# 3  Vedant   87.0    Male  vedant@yahoo.com
# 5  Mittal   83.0  Female  mittal@yahoo.com

# %%
sum(df['Marks'].between(80,90))
# Out:
# 2

# %%
df[df['Marks'] == df['Marks'].min()].loc[:,['Name', 'Marks']]
# Out:
#      Name  Marks
# 5  Mittal   83.0

# %%
df['Marks'].sort_values(ascending=False)
# Out:
# 2    99.0
# 6    99.0
# 0    98.0
# 1    93.2
# 4    93.2
# 3    87.0
# 5    83.0
# Name: Marks, dtype: float64

# %%
df \
.sort_values(by='Marks', ascending=False) \
.head()
# Out:
#       Name  Marks  Gender               Email
# 2   Krisha   99.0  Female    krisha@gmail.com
# 6  Archana   99.0  Female   archana@yahoo.com
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya   93.2  Female    aadhya@gmail.com
# 4   Parshv   93.2    Male  parshv@hotmail.com

# %%
df.nlargest(5, 'Marks')
# Out:
#       Name  Marks  Gender               Email
# 2   Krisha   99.0  Female    krisha@gmail.com
# 6  Archana   99.0  Female   archana@yahoo.com
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya   93.2  Female    aadhya@gmail.com
# 4   Parshv   93.2    Male  parshv@hotmail.com

# %%
df.iloc[:,:]
# Out:
#       Name  Marks  Gender               Email
# 0  Priyang   98.0    Male   priyang@gmail.com
# 1   Aadhya   93.2  Female    aadhya@gmail.com
# 2   Krisha   99.0  Female    krisha@gmail.com
# 3   Vedant   87.0    Male    vedant@yahoo.com
# 4   Parshv   93.2    Male  parshv@hotmail.com
# 5   Mittal   83.0  Female    mittal@yahoo.com
# 6  Archana   99.0  Female   archana@yahoo.com

# %%
df.iloc[1:4, 1:4]
# Out:
#    Marks  Gender             Email
# 1   93.2  Female  aadhya@gmail.com
# 2   99.0  Female  krisha@gmail.com
# 3   87.0    Male  vedant@yahoo.com

# %%
df.iloc[[1,3,4], [1,2,3]]
# Out:
#    Marks  Gender               Email
# 1   93.2  Female    aadhya@gmail.com
# 3   87.0    Male    vedant@yahoo.com
# 4   93.2    Male  parshv@hotmail.com

# %%
df.nlargest(5, 'Marks')[['Name', 'Marks']]
# Out:
#       Name  Marks
# 2   Krisha   99.0
# 6  Archana   99.0
# 0  Priyang   98.0
# 1   Aadhya   93.2
# 4   Parshv   93.2

# %%
df.columns
# Out:
# Index(['Name', 'Marks', 'Gender', 'Email'], dtype='object')

# %%
df['Marks'].mean()
# Out:
# 93.2

# %%
df['Marks'].min()
# Out:
# 83.0

# %%
def marks(x):
    return x/2

df['Half Marks']=df['Marks'].apply(marks)
# df.drop(columns=['New Marks'], axis=1, inplace=True)
df
# Out:
#       Name  Marks  Gender               Email  Half Marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5

# %%
df['Male or Female'] = df['Gender'].map({'Female': 0, 'Male': 1})

# %%
df
# Out:
#       Name  Marks  Gender               Email  Half Marks  Male or Female
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0               1
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6               0
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5               0
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5               1
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6               1
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5               0
# 6  Archana   99.0  Female   archana@yahoo.com        49.5               0

# %%
df.drop(columns=['Male or Female'], axis=1, inplace=True)
df
# Out:
#       Name  Marks  Gender               Email  Half Marks
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5

# %%
df.sort_values(by='Marks', ascending=False)
# Out:
#       Name  Marks  Gender               Email  Half Marks
# 2   Krisha   99.0  Female    krisha@gmail.com        49.5
# 6  Archana   99.0  Female   archana@yahoo.com        49.5
# 0  Priyang   98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya   93.2  Female    aadhya@gmail.com        46.6
# 4   Parshv   93.2    Male  parshv@hotmail.com        46.6
# 3   Vedant   87.0    Male    vedant@yahoo.com        43.5
# 5   Mittal   83.0  Female    mittal@yahoo.com        41.5

# %%
df[df['Gender'] == 'Female'][['Name', 'Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   93.2
# 2   Krisha   99.0
# 5   Mittal   83.0
# 6  Archana   99.0

# %%
df[df['Gender'].isin(['Female'])][['Name', 'Marks']]
# Out:
#       Name  Marks
# 1   Aadhya   93.2
# 2   Krisha   99.0
# 5   Mittal   83.0
# 6  Archana   99.0

# %%
df.rename(columns={'Marks': 'Final Marks'}, inplace=True)

# %%
df
# Out:
#       Name  Final Marks  Gender               Email  Half Marks
# 0  Priyang         98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya         93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha         99.0  Female    krisha@gmail.com        49.5
# 3   Vedant         87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv         93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal         83.0  Female    mittal@yahoo.com        41.5
# 6  Archana         99.0  Female   archana@yahoo.com        49.5

# %%
df_ = pd.DataFrame({
    'Name': 'Anil',
    'Marks': 90,
    'Gender': 'Male',
    'Email': 'anil@gmail.com',
}, index=[0])
df_
# Out:
#    Name  Marks Gender           Email
# 0  Anil     90   Male  anil@gmail.com

# %%
df1 = pd.concat([df,df_], axis=0, ignore_index=True)
df1.loc[7, 'Final Marks'] = df1.loc[7, 'Marks']
df1.drop(axis=1, columns=['Half Marks', 'Marks'], inplace=True)
df1
# Out:
#       Name  Final Marks  Gender               Email
# 0  Priyang         98.0    Male   priyang@gmail.com
# 1   Aadhya         93.2  Female    aadhya@gmail.com
# 2   Krisha         99.0  Female    krisha@gmail.com
# 3   Vedant         87.0    Male    vedant@yahoo.com
# 4   Parshv         93.2    Male  parshv@hotmail.com
# 5   Mittal         83.0  Female    mittal@yahoo.com
# 6  Archana         99.0  Female   archana@yahoo.com
# 7     Anil         90.0    Male      anil@gmail.com

# %%
df.loc[:, 'Final Marks':'Email']
# Out:
#    Final Marks  Gender               Email
# 0         98.0    Male   priyang@gmail.com
# 1         93.2  Female    aadhya@gmail.com
# 2         99.0  Female    krisha@gmail.com
# 3         87.0    Male    vedant@yahoo.com
# 4         93.2    Male  parshv@hotmail.com
# 5         83.0  Female    mittal@yahoo.com
# 6         99.0  Female   archana@yahoo.com

# %%
df.loc[2:6, ['Email']]

#loc[rows, columns]
# loc[2, 3]
# Out:
#                 Email
# 2    krisha@gmail.com
# 3    vedant@yahoo.com
# 4  parshv@hotmail.com
# 5    mittal@yahoo.com
# 6   archana@yahoo.com

# %%
df.iloc[1, 2]
# Out:
# 'Female'

# %%
df.iloc[1, :]
# Out:
# Name                     Aadhya
# Final Marks                93.2
# Gender                   Female
# Email          aadhya@gmail.com
# Half Marks                 46.6
# Name: 1, dtype: object

# %%
df.iloc[:, 1]
# Out:
# 0    98.0
# 1    93.2
# 2    99.0
# 3    87.0
# 4    93.2
# 5    83.0
# 6    99.0
# Name: Final Marks, dtype: float64

# %%
df.iloc[:,:]
# Out:
#       Name  Final Marks  Gender               Email  Half Marks
# 0  Priyang         98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya         93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha         99.0  Female    krisha@gmail.com        49.5
# 3   Vedant         87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv         93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal         83.0  Female    mittal@yahoo.com        41.5
# 6  Archana         99.0  Female   archana@yahoo.com        49.5

# %%
df.iloc[[1,3,5], 2:5]
# Out:
#    Gender             Email  Half Marks
# 1  Female  aadhya@gmail.com        46.6
# 3    Male  vedant@yahoo.com        43.5
# 5  Female  mittal@yahoo.com        41.5

# %%
df['Final Marks'] + df['Final Marks']
# Out:
# 0    196.0
# 1    186.4
# 2    198.0
# 3    174.0
# 4    186.4
# 5    166.0
# 6    198.0
# Name: Final Marks, dtype: float64

# %%
df['Name'] + str(df['Final Marks'])
# Out:
# 0    Priyang0    98.0\n1    93.2\n2    99.0\n3    8...
# 1    Aadhya0    98.0\n1    93.2\n2    99.0\n3    87...
# 2    Krisha0    98.0\n1    93.2\n2    99.0\n3    87...
# 3    Vedant0    98.0\n1    93.2\n2    99.0\n3    87...
# 4    Parshv0    98.0\n1    93.2\n2    99.0\n3    87...
# 5    Mittal0    98.0\n1    93.2\n2    99.0\n3    87...
# 6    Archana0    98.0\n1    93.2\n2    99.0\n3    8...
# Name: Name, dtype: object

# %%
df.T
# Out:
#                              0                 1                 2  \
# Name                   Priyang            Aadhya            Krisha
# Final Marks               98.0              93.2              99.0
# Gender                    Male            Female            Female
# Email        priyang@gmail.com  aadhya@gmail.com  krisha@gmail.com
# Half Marks                49.0              46.6              49.5
#
#                             3                   4                 5  \
# Name                   Vedant              Parshv            Mittal
# Final Marks              87.0                93.2              83.0
# Gender                   Male                Male            Female
# Email        vedant@yahoo.com  parshv@hotmail.com  mittal@yahoo.com
# Half Marks               43.5                46.6              41.5
#
#                              6
# Name                   Archana
# Final Marks               99.0
# Gender                  Female
# ...

# %%
(df.groupby('Gender')['Final Marks'].mean().to_frame().reset_index())
# Out:
#    Gender  Final Marks
# 0  Female    93.550000
# 1    Male    92.733333

# %%
type(df.groupby('Gender')['Final Marks'].mean().to_frame().reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#       Name  Final Marks  Gender               Email  Half Marks
# 0  Priyang         98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya         93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha         99.0  Female    krisha@gmail.com        49.5
# 3   Vedant         87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv         93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal         83.0  Female    mittal@yahoo.com        41.5
# 6  Archana         99.0  Female   archana@yahoo.com        49.5

# %%
df['Email Extension'] = df['Email'].apply(lambda x: x.split('@')[1])
df
# Out:
#       Name  Final Marks  Gender               Email  Half Marks  \
# 0  Priyang         98.0    Male   priyang@gmail.com        49.0
# 1   Aadhya         93.2  Female    aadhya@gmail.com        46.6
# 2   Krisha         99.0  Female    krisha@gmail.com        49.5
# 3   Vedant         87.0    Male    vedant@yahoo.com        43.5
# 4   Parshv         93.2    Male  parshv@hotmail.com        46.6
# 5   Mittal         83.0  Female    mittal@yahoo.com        41.5
# 6  Archana         99.0  Female   archana@yahoo.com        49.5
#
#   Email Extension
# 0       gmail.com
# 1       gmail.com
# 2       gmail.com
# 3       yahoo.com
# 4     hotmail.com
# 5       yahoo.com
# 6       yahoo.com

# %%
df['Email Extension'].value_counts().sort_values(ascending=False)
# Out:
# Email Extension
# gmail.com      3
# yahoo.com      3
# hotmail.com    1
# Name: count, dtype: int64

# %%
df['Email'].apply(lambda x: x.split('@')[1]).value_counts().head()
# Out:
# Email
# gmail.com      3
# yahoo.com      3
# hotmail.com    1
# Name: count, dtype: int64
