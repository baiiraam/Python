# %% [markdown]
# # Getting Started with Data Analysis - Installation and Loading Data

# %%
import pandas as pd

survey_results_df = pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_public.csv')

# %%
survey_results_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey_results_df.shape
# Out:
# (88883, 85)

# %%
survey_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

survey_results_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df = pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_schema.csv')

schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df.head()
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...

# %%
schema_df.head(8)
# Out:
#         Column                                       QuestionText
# 0   Respondent  Randomized respondent ID number (not in order ...
# 1   MainBranch  Which of the following options best describes ...
# 2     Hobbyist                            Do you code as a hobby?
# 3  OpenSourcer        How often do you contribute to open source?
# 4   OpenSource  How do you feel about the quality of open sour...
# 5   Employment  Which of the following best describes your cur...
# 6      Country          In which country do you currently reside?
# 7      Student  Are you currently enrolled in a formal, degree...

# %%
schema_df.tail()
# Out:
#           Column                                       QuestionText
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...

# %%
schema_df.tail(4)
# Out:
#           Column                                       QuestionText
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...

# %% [markdown]
# # DataFrame and Series Basics - Selecting Rows and Columns

# %%
people = {
    'first': ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Doe'],
    'email':['CoreySchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']
}

# %%
people['email']
# Out:
# ['CoreySchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']

# %%
df = pd.DataFrame(people)

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df['email']
# Out:
# 0    CoreySchafer@gmail.com
# 1         JaneDoe@gmail.com
# 2         JohnDoe@gmail.com
# Name: email, dtype: object

# %%
type(df['email'])
# Out:
# pandas.core.series.Series

# %%
df['email'][0]
# Out:
# 'CoreySchafer@gmail.com'

# %%
df.email
# Out:
# 0    CoreySchafer@gmail.com
# 1         JaneDoe@gmail.com
# 2         JohnDoe@gmail.com
# Name: email, dtype: object

# %%
df.email[2]
# Out:
# 'JohnDoe@gmail.com'

# %%
df[['last', 'email']]
# Out:
#       last                   email
# 0  Schafer  CoreySchafer@gmail.com
# 1      Doe       JaneDoe@gmail.com
# 2      Doe       JohnDoe@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
#  iloc - integer location

# df.iloc[row]

df.iloc[0]
# Out:
# first                     Corey
# last                    Schafer
# email    CoreySchafer@gmail.com
# Name: 0, dtype: object

# %%
# df.iloc[[starting row, ending row]]

df.iloc[[0, 1]]
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com

# %%
# df.iloc[[starting row, ending row], column]

df.iloc[[0, 1], 2]
# Out:
# 0    CoreySchafer@gmail.com
# 1         JaneDoe@gmail.com
# Name: email, dtype: object

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df.loc[0]
# Out:
# first                     Corey
# last                    Schafer
# email    CoreySchafer@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[0, 1]]
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com

# %%
df.loc[[0, 1], 'email']
# Out:
# 0    CoreySchafer@gmail.com
# 1         JaneDoe@gmail.com
# Name: email, dtype: object

# %%
df.loc[[0, 1], ['email', 'last']]
# Out:
#                     email     last
# 0  CoreySchafer@gmail.com  Schafer
# 1       JaneDoe@gmail.com      Doe

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
survey_results_df.shape
# Out:
# (88883, 85)

# %%
survey_results_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey_results_df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
survey_results_df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
survey_results_df['Hobbyist'].value_counts()['Yes']
# Out:
# 71257

# %%
survey_results_df.loc[0]
# Out:
# Respondent                                                                1
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# ...

# %%
survey_results_df.loc[0, 'Hobbyist']
# Out:
# 'Yes'

# %%
# .loc[row, column]

# %%
survey_results_df.loc[[0,1,2], 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
survey_results_df.loc[0:2, 'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
survey_results_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
survey_results_df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# # Indexes - How to Set, Reset, and Use Indexes

# %%
df['email']
# Out:
# 0    CoreySchafer@gmail.com
# 1         JaneDoe@gmail.com
# 2         JohnDoe@gmail.com
# Name: email, dtype: object

# %%
df.set_index('email')
# Out:
#                         first     last
# email
# CoreySchafer@gmail.com  Corey  Schafer
# JaneDoe@gmail.com        Jane      Doe
# JohnDoe@gmail.com        John      Doe

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                         first     last
# email
# CoreySchafer@gmail.com  Corey  Schafer
# JaneDoe@gmail.com        Jane      Doe
# JohnDoe@gmail.com        John      Doe

# %%
df.index
# Out:
# Index(['CoreySchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com'], dtype='object', name='email')

# %%
df.loc['CoreySchafer@gmail.com']
# Out:
# first      Corey
# last     Schafer
# Name: CoreySchafer@gmail.com, dtype: object

# %%
df.loc['CoreySchafer@gmail.com', 'last']
# Out:
# 'Schafer'

# %%
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreySchafer@gmail.com, dtype: object

# %%
df.reset_index(inplace=True)
df
# Out:
#                     email  first     last
# 0  CoreySchafer@gmail.com  Corey  Schafer
# 1       JaneDoe@gmail.com   Jane      Doe
# 2       JohnDoe@gmail.com   John      Doe

# %%
survey_results_df = pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col='Respondent')

survey_results_df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey_results_df.loc[1]

# Now labels start from 1 ----> Respondent 1, Respondent 2, ...
# Out:
# MainBranch                           I am a student who is learning to code
# Hobbyist                                                                Yes
# OpenSourcer                                                           Never
# OpenSource                The quality of OSS and closed source software ...
# Employment                           Not employed, and not looking for work
# Country                                                      United Kingdom
# Student                                                                  No
# EdLevel                                           Primary/elementary school
# UndergradMajor                                                          NaN
# EduOther                  Taught yourself a new language, framework, or ...
# OrgSize                                                                 NaN
# DevType                                                                 NaN
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
schema_df = pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_schema.csv', index_col='Column')

schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index()
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %% [markdown]
# # Filtering - Using Conditionals to Filter Rows and Columns

# %%
df
# Out:
#                     email  first     last
# 0  CoreySchafer@gmail.com  Corey  Schafer
# 1       JaneDoe@gmail.com   Jane      Doe
# 2       JohnDoe@gmail.com   John      Doe

# %%
filt = (df['last'] == 'Doe')

# %%
df[filt]
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %%
df[df['last'] == 'Doe']
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %%
df.loc[filt]
# Out:
#                email first last
# 1  JaneDoe@gmail.com  Jane  Doe
# 2  JohnDoe@gmail.com  John  Doe

# %%
# .loc[row, column]

df.loc[filt ,'email']
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
df.loc[filt]['email']
# Out:
# 1    JaneDoe@gmail.com
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
df.loc[filt]['email'][1]
# Out:
# 'JaneDoe@gmail.com'

# %% [raw]
# & - and
# | - or

# %%
filt1 = (df['last'] == 'Doe') & (df['first'] == 'John')

# %%
df[filt1]
# Out:
#                email first last
# 2  JohnDoe@gmail.com  John  Doe

# %%
df.loc[filt1, 'email']
# Out:
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
df[filt1]['email']
# Out:
# 2    JohnDoe@gmail.com
# Name: email, dtype: object

# %%
filt2 = (df['last'] == 'Schafer') | (df['first'] == 'John')

# %%
df[filt2]
# Out:
#                     email  first     last
# 0  CoreySchafer@gmail.com  Corey  Schafer
# 2       JohnDoe@gmail.com   John      Doe

# %%
df.loc[filt2, 'first':'last']
# Out:
#    first     last
# 0  Corey  Schafer
# 2   John      Doe

# %%
# .loc[row, column]

df.loc[filt2, 'email']
# Out:
# 0    CoreySchafer@gmail.com
# 2         JohnDoe@gmail.com
# Name: email, dtype: object

# %%
df[filt2]['first']
# Out:
# 0    Corey
# 2     John
# Name: first, dtype: object

# %%
# ~ means NOT

df.loc[~filt2, 'email']
# Out:
# 1    JaneDoe@gmail.com
# Name: email, dtype: object

# %%
# ~ not
# | or
# & and

# %%
# about salary

high_salary = (survey_results_df['ConvertedComp'] > 70000)

# filter the respondents whose salary is greater than 70,000

# %%
survey_results_df.loc[high_salary]

# show them
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 13                             I am a developer by profession      Yes
# 16                             I am a developer by profession      Yes
# 22                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88876                          I am a developer by profession      Yes
# 88877                          I am a developer by profession      Yes
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
# survey_results_df.set_index('Respondent', inplace=True)

# setting index column(first column as 'Respondent'),   inplace=True  applying it to our survey_results_df DataFrame

survey_results_df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]

# .loc[row, column]    filtering high_salary, showing columns 'Country', 'LanguageWorkedWith', 'ConvertedComp'. Remember to put them in a list 
# since there are multiple variables. It is not a range, we want to view these columns in our DataFrame.
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
# ...

# %%
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt3 = survey_results_df['Country'].isin(countries)

# %%
survey_results_df.loc[filt3, 'Country']
# Out:
# Respondent
# 1        United Kingdom
# 4         United States
# 6                Canada
# 8                 India
# 10                India
#               ...
# 85642     United States
# 85961    United Kingdom
# 86012             India
# 88282     United States
# 88377            Canada
# Name: Country, Length: 45008, dtype: object

# %%
survey_results_df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt4 = survey_results_df['LanguageWorkedWith'].str.contains('Python', na=False)

survey_results_df.loc[filt4, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
filt4
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
#          ...
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
survey_results_df.loc[filt4]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
# 4                   I am a developer by profession       No
# 5                   I am a developer by profession      Yes
# 8                      I code primarily as a hobby      Yes
# ...                                            ...      ...
# 84539                                          NaN      Yes
# 85738                                          NaN      Yes
# 86566                                          NaN      Yes
# 87739                                          NaN      Yes
# 88212                                          NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# ...

# %% [markdown]
# # Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df = pd.DataFrame(people)

# Turn dictionary into DataFrame in Pandas
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns = ['first_name', 'last_name', 'email']

df.columns
# Out:
# Index(['first_name', 'last_name', 'email'], dtype='object')

# %%
df
# Out:
#   first_name last_name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
df.columns = [x.upper() for x in df.columns]

# List Comprehension. Changing column names to their uppercase.

df
# Out:
#   FIRST_NAME LAST_NAME                   EMAIL
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
df.columns = df.columns.str.replace(' ', '_')

df
# Out:
#   FIRST_NAME LAST_NAME                   EMAIL
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
df.columns = [x.lower() for x in df.columns]

df
# Out:
#   first_name last_name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
df.rename(columns={'first_name': 'first', 'last_name':'last'})
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df
# Out:
#   first_name last_name                   email
# 0      Corey   Schafer  CoreySchafer@gmail.com
# 1       Jane       Doe       JaneDoe@gmail.com
# 2       John       Doe       JohnDoe@gmail.com

# %%
df.rename(columns={'first_name': 'first', 'last_name':'last'}, inplace=True)

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df.loc[2]
# Out:
# first                 John
# last                   Doe
# email    JohnDoe@gmail.com
# Name: 2, dtype: object

# %%
df[(df['first'] == 'John') & (df['last'] == 'Doe')]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@gmail.com

# %%
df.loc[2] = ['John', 'Smith', 'JohnSmith@gmail.com']

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John    Smith     JohnSmith@gmail.com

# %%
df.loc[2, ['last', 'email']]
# Out:
# last                   Smith
# email    JohnSmith@gmail.com
# Name: 2, dtype: object

# %%
df.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@gmail.com']

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df.loc[2,'last'] = 'Smith'

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John    Smith       JohnDoe@gmail.com

# %%
df.at[2, 'last'] = 'Doe'

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
filt5 = (df['email'] == 'JohnDoe@gmail.com')

df[filt5]
# Out:
#   first last              email
# 2  John  Doe  JohnDoe@gmail.com

# %%
df[filt5]['last']
# Out:
# 2    Doe
# Name: last, dtype: object

# %%
# Don't do this --> df[filt5]['last'] = 'Smith'

# %%
df.loc[filt5, 'last'] = 'Smith'

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John    Smith       JohnDoe@gmail.com

# %%
df['email'].str.lower()
# Out:
# 0    coreyschafer@gmail.com
# 1         janedoe@gmail.com
# 2         johndoe@gmail.com
# Name: email, dtype: object

# %%
df['email'] = df['email'].str.lower()

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %% [markdown]
# * apply
# * map
# * applymap
# * replace

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    COREYSCHAFER@GMAIL.COM
# 1         JANEDOE@GMAIL.COM
# 2         JOHNDOE@GMAIL.COM
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(update_email)

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  COREYSCHAFER@GMAIL.COM
# 1   Jane      Doe       JANEDOE@GMAIL.COM
# 2   John    Smith       JOHNDOE@GMAIL.COM

# %%
df['email'] = df['email'].apply(lambda x : x.lower())

df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gmail.com
# 1   Jane      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
len(df['email'])
# Out:
# 3

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                     Corey
# last                        Doe
# email    coreyschafer@gmail.com
# dtype: object

# %%
df.apply(lambda x: x.min())
# Out:
# first                     Corey
# last                        Doe
# email    coreyschafer@gmail.com
# dtype: object

# %%
# applymap has been deprecated. It gave an error.

df.map(len)
# Out:
#    first  last  email
# 0      5     7     22
# 1      4     3     17
# 2      4     5     17

# %%
df.map(str.lower)

# df.map(str.upper)
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 1   jane      doe       janedoe@gmail.com
# 2   john    smith       johndoe@gmail.com

# %%
df['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: object

# %%
df['first'] = df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})

df
# Out:
#    first     last                   email
# 0  Chris  Schafer  coreyschafer@gmail.com
# 1   Mary      Doe       janedoe@gmail.com
# 2   John    Smith       johndoe@gmail.com

# %% [markdown]
# real world example

# %%
# survey_results_df

# %%
# survey_results_df.rename(columns={'ConvertedComp': 'SalaryUSD'})

# survey_results_df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# survey_results_df

# %%
# survey_results_df['SalaryUSD']

# %%
# survey_results_df.loc[:, ['SalaryUSD']]  --  I did that just for fun

# survey_results_df['Hobbyist']

# %%
# survey_results_df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
# survey_results_df['Hobbyist'] = survey_results_df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
# All of the comments above is because there was a slight error in the code.

survey_results_df = pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_public.csv')

survey_results_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey_results_df['Hobbyist'] = survey_results_df['Hobbyist'].map({'Yes': True, 'No': False})

# %%
survey_results_df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 88878       88377                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
# 88882       88863                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 0          True                                              Never
# ...

# %%
survey_results_df.loc[:, ['Hobbyist']]
# Out:
#        Hobbyist
# 0          True
# 1         False
# 2          True
# 3         False
# 4          True
# ...         ...
# 88878      True
# 88879     False
# 88880     False
# 88881     False
# 88882      True
#
# [88883 rows x 1 columns]

# %% [markdown]
# # Add/Remove Rows and Columns From DataFrames

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    Chris Schafer
# 1         Mary Doe
# 2       John Smith
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                   email      full_name
# 0  Chris  Schafer  coreyschafer@gmail.com  Chris Schafer
# 1   Mary      Doe       janedoe@gmail.com       Mary Doe
# 2   John    Smith       johndoe@gmail.com     John Smith

# %%
df.drop(columns=['first', 'last'])
# Out:
#                     email      full_name
# 0  coreyschafer@gmail.com  Chris Schafer
# 1       janedoe@gmail.com       Mary Doe
# 2       johndoe@gmail.com     John Smith

# %%
df.drop(columns=['first', 'last'], inplace=True)

# %%
df
# Out:
#                     email      full_name
# 0  coreyschafer@gmail.com  Chris Schafer
# 1       janedoe@gmail.com       Mary Doe
# 2       johndoe@gmail.com     John Smith

# %%
df['full_name'].str.split(' ')
# Out:
# 0    [Chris, Schafer]
# 1         [Mary, Doe]
# 2       [John, Smith]
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Chris  Schafer
# 1   Mary      Doe
# 2   John    Smith

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1       janedoe@gmail.com       Mary Doe   Mary      Doe
# 2       johndoe@gmail.com     John Smith   John    Smith

# %%
df._append({'first': 'Tony'}, ignore_index=True)

# append is  _append
# NaN - missing value,or Not a Number
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1       janedoe@gmail.com       Mary Doe   Mary      Doe
# 2       johndoe@gmail.com     John Smith   John    Smith
# 3                     NaN            NaN   Tony      NaN

# %%
people
# Out:
# {'first': ['Corey', 'Jane', 'John'],
#  'last': ['Schafer', 'Doe', 'Doe'],
#  'email': ['CoreySchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com']}

# %%
people1 = {'first': ['Tony', 'Steve'],
           'last': ['Stark', 'Rogers'],
          'email': ['IronMan@avenge.com', 'Cap@avenge.com']
         }
df2 = pd.DataFrame(people1)

# %%
df2
# Out:
#    first    last               email
# 0   Tony   Stark  IronMan@avenge.com
# 1  Steve  Rogers      Cap@avenge.com

# %%
df._append(df2, ignore_index=True)
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1       janedoe@gmail.com       Mary Doe   Mary      Doe
# 2       johndoe@gmail.com     John Smith   John    Smith
# 3      IronMan@avenge.com            NaN   Tony    Stark
# 4          Cap@avenge.com            NaN  Steve   Rogers

# %%
df = df._append(df2, ignore_index=True)

# %%
df
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1       janedoe@gmail.com       Mary Doe   Mary      Doe
# 2       johndoe@gmail.com     John Smith   John    Smith
# 3      IronMan@avenge.com            NaN   Tony    Stark
# 4          Cap@avenge.com            NaN  Steve   Rogers

# %%
df.drop(index=4)

# inplace=True can be done to make it permanent
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  Chris Schafer  Chris  Schafer
# 1       janedoe@gmail.com       Mary Doe   Mary      Doe
# 2       johndoe@gmail.com     John Smith   John    Smith
# 3      IronMan@avenge.com            NaN   Tony    Stark

# %%
df.drop(index = (df[df['last'] == 'Doe']).index)

# Removed rows with lastname 'Doe'.
# With a conditional
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2       johndoe@gmail.com     John Smith   John    Smith
# 3      IronMan@avenge.com            NaN   Tony    Stark
# 4          Cap@avenge.com            NaN  Steve   Rogers

# %%
filtt = (df['last'] == 'Doe')
df.drop(index=df[filtt].index)
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  Chris Schafer  Chris  Schafer
# 2       johndoe@gmail.com     John Smith   John    Smith
# 3      IronMan@avenge.com            NaN   Tony    Stark
# 4          Cap@avenge.com            NaN  Steve   Rogers

# %% [markdown]
# # Sorting Data

# %%
people = {'first': ['Corey', 'Jane', 'John', 'Adam'],
 'last': ['Schafer', 'Doe', 'Doe', 'Doe'],
 'email': ['CoreySchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com', 'A@gmail.com']}

df1 = pd.DataFrame(people)

# %%
df1.sort_values(by='last')
# Out:
#    first     last                   email
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 3   Adam      Doe             A@gmail.com
# 0  Corey  Schafer  CoreySchafer@gmail.com

# %%
df1.sort_values(by='last', ascending=False)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 3   Adam      Doe             A@gmail.com

# %%
df1.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 3   Adam      Doe             A@gmail.com

# %%
people
# Out:
# {'first': ['Corey', 'Jane', 'John', 'Adam'],
#  'last': ['Schafer', 'Doe', 'Doe', 'Doe'],
#  'email': ['CoreySchafer@gmail.com',
#   'JaneDoe@gmail.com',
#   'JohnDoe@gmail.com',
#   'A@gmail.com']}

# %%
df1.sort_values(by=['last', 'first'], ascending=[False, True])
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 3   Adam      Doe             A@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df1.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df1
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 3   Adam      Doe             A@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com

# %%
df1.sort_index()
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gmail.com
# 1   Jane      Doe       JaneDoe@gmail.com
# 2   John      Doe       JohnDoe@gmail.com
# 3   Adam      Doe             A@gmail.com

# %%
df['last'].sort_values()
# Out:
# 1        Doe
# 4     Rogers
# 0    Schafer
# 2      Smith
# 3      Stark
# Name: last, dtype: object

# %%
survey_results_df
# Out:
#        Respondent                                         MainBranch  \
# 0               1             I am a student who is learning to code
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 88878       88377                                                NaN
# 88879       88601                                                NaN
# 88880       88802                                                NaN
# 88881       88816                                                NaN
# 88882       88863                                                NaN
#
#        Hobbyist                                        OpenSourcer  \
# 0          True                                              Never
# ...

# %%
survey_results_df.sort_values(by='Country', inplace=True)

# %%
survey_results_df['Country'].head(50)
# Out:
# 39018    Afghanistan
# 62723    Afghanistan
# 85185    Afghanistan
# 50437    Afghanistan
# 88340    Afghanistan
# 88735    Afghanistan
# 6391     Afghanistan
# 39754    Afghanistan
# 88181    Afghanistan
# 48122    Afghanistan
# 10697    Afghanistan
# 62124    Afghanistan
# 49377    Afghanistan
# 32971    Afghanistan
# 60559    Afghanistan
# 85827    Afghanistan
# 88033    Afghanistan
# 28470    Afghanistan
# 719      Afghanistan
# 26189    Afghanistan
# 86394    Afghanistan
# 85293    Afghanistan
# 7056     Afghanistan
# 7323     Afghanistan
# 86551    Afghanistan
# 58390    Afghanistan
# 73920    Afghanistan
# 28877    Afghanistan
# 51525    Afghanistan
# 45562    Afghanistan
# 46807    Afghanistan
# 44123    Afghanistan
# 22327    Afghanistan
# 8112     Afghanistan
# 80423    Afghanistan
# 59184    Afghanistan
# 60185    Afghanistan
# 37571    Afghanistan
# 29560    Afghanistan
# 42832    Afghanistan
# 12253    Afghanistan
# 58082    Afghanistan
# 61770    Afghanistan
# ...

# %%
survey_results_df[['Country', 'ConvertedComp']].head(50)
# Out:
#            Country  ConvertedComp
# 39018  Afghanistan        19152.0
# 62723  Afghanistan      1000000.0
# 85185  Afghanistan            NaN
# 50437  Afghanistan            NaN
# 88340  Afghanistan            NaN
# 88735  Afghanistan            NaN
# 6391   Afghanistan            NaN
# 39754  Afghanistan            NaN
# 88181  Afghanistan            NaN
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 62124  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 60559  Afghanistan            NaN
# 85827  Afghanistan            NaN
# 88033  Afghanistan            NaN
# 28470  Afghanistan            0.0
# 719    Afghanistan            0.0
# 26189  Afghanistan            NaN
# 86394  Afghanistan            NaN
# 85293  Afghanistan            NaN
# 7056   Afghanistan        14364.0
# 7323   Afghanistan            NaN
# 86551  Afghanistan            NaN
# 58390  Afghanistan            NaN
# ...

# %%
survey_results_df[['Country', 'ConvertedComp']].sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False]).head(50)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# 22327  Afghanistan         7980.0
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 8112   Afghanistan         1596.0
# 29560  Afghanistan         1116.0
# 28470  Afghanistan            0.0
# 719    Afghanistan            0.0
# 85185  Afghanistan            NaN
# 50437  Afghanistan            NaN
# 88340  Afghanistan            NaN
# 88735  Afghanistan            NaN
# 6391   Afghanistan            NaN
# 39754  Afghanistan            NaN
# 88181  Afghanistan            NaN
# 62124  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 60559  Afghanistan            NaN
# 85827  Afghanistan            NaN
# 88033  Afghanistan            NaN
# 26189  Afghanistan            NaN
# ...

# %%
survey_results_df['ConvertedComp'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
survey_results_df.nlargest(10, 'ConvertedComp')
# Out:
#        Respondent                                         MainBranch  \
# 25833       25983                     I am a developer by profession
# 87353       87896                     I am a developer by profession
# 21895       22013                     I am a developer by profession
# 28080       28243                     I am a developer by profession
# 72274       72732  I am not primarily a developer, but I write co...
# 77665       78151                     I am a developer by profession
# 79701       80200                     I am a developer by profession
# 51798       52132                     I am a developer by profession
# 75088       75561                     I am a developer by profession
# 32056       32250                     I am a developer by profession
#
#        Hobbyist                                        OpenSourcer  \
# 25833      True                            Less than once per year
# 87353      True                            Less than once per year
# ...

# %%
survey_results_df.nsmallest(10, 'ConvertedComp')
# Out:
#        Respondent                                         MainBranch  \
# 28470       28638                     I am a developer by profession
# 719           722                     I am a developer by profession
# 13760       13825                     I am a developer by profession
# 40655       40913                     I am a developer by profession
# 30447       30630                     I am a developer by profession
# 68611       69049                     I am a developer by profession
# 19235       19340  I am not primarily a developer, but I write co...
# 16126       16214  I am not primarily a developer, but I write co...
# 29184       29355                     I am a developer by profession
# 1678         1685                     I am a developer by profession
#
#        Hobbyist                                        OpenSourcer  \
# 28470      True  Less than once a month but more than once per ...
# 719       False  Less than once a month but more than once per ...
# ...

# %% [markdown]
# # Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
survey_results_df['ConvertedComp'].head(15)
# Out:
# 39018      19152.0
# 62723    1000000.0
# 85185          NaN
# 50437          NaN
# 88340          NaN
# 88735          NaN
# 6391           NaN
# 39754          NaN
# 88181          NaN
# 48122       4464.0
# 10697       3996.0
# 62124          NaN
# 49377          NaN
# 32971          NaN
# 60559          NaN
# Name: ConvertedComp, dtype: float64

# %%
# changing the variable name so it will be easy for me

# srdf -- SurveyResultsDataFrame

srdf = pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_public.csv')

# %%
srdf.set_index('Respondent')
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
srdf['ConvertedComp'].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2       8820.0
# 3      61000.0
# 4          NaN
# 5     366420.0
# 6          NaN
# 7          NaN
# 8      95179.0
# 9      13293.0
# 10         NaN
# 11         NaN
# 12     90000.0
# 13     57060.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
srdf['ConvertedComp'].median()
# Out:
# 57287.0

# %%
srdf.median(numeric_only=True).drop('Respondent')

# median of our dataframe.
# median of Respondents does not make sense. We drop it.
# Out:
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
srdf.describe().drop(columns='Respondent')
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
srdf.describe().drop('25%').drop('50%').drop('75%').drop(columns='Respondent')
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
a = srdf['ConvertedComp'].count()

# How many people answered this question?

a
# Out:
# 55823

# %%
b = srdf['Respondent'].count()

b
# Out:
# 88883

# %%
f'{b-a} people did not answer this question'
# Out:
# '33060 people did not answer this question'

# %%
srdf['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
srdf['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
srdf['SocialMedia']
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
srdf['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
schema_df.loc['SocialMedia']

# .loc[rows, columns]
# or
# .loc[rows]
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
srdf['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
srdf['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
srdf.set_index('Respondent')['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_grp = srdf.set_index('Respondent').groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_19580\1353200628.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('United States')
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
# ...

# %%
country_grp.get_group('India')
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_19580\421256909.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('India')
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# ...

# %%
filtt1 = (srdf['Country'] == 'United States')
srdf.loc[filtt1].set_index('Respondent')
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 4                                                       Never
# 13          Less than once a month but more than once per ...
# 22                                    Less than once per year
# ...

# %%
srdf.loc[filtt1]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      5700
# Twitter                     3468
# Facebook                    2844
# YouTube                     2463
# I don't use social media    1851
# Instagram                   1652
# LinkedIn                    1020
# WhatsApp                     609
# Snapchat                     326
# WeChat 微信                     93
# VK ВКонта́кте                  9
# Weibo 新浪微博                     8
# Hello                          2
# Youku Tudou 优酷                 1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().head(40)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: proportion, dtype: float64

# %%
country_grp['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: count, dtype: int64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
srdf.groupby('Country')['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
# agg -- aggregate

country_grp['ConvertedComp'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filtt2 = (srdf['Country'] == 'India')

srdf.loc[filtt2]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()

# error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[957], line 1
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#       3 # error
#
# File c:\users\bayram\appdata\local\programs\python\python39\lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
srdf.groupby(['Country'])['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# # How many people from each country know Python?
# First, we need to know total number of respondents from each country

# %% [markdown]
# ## Total number of respondents from each country

# %%
country_respondents = srdf['Country'].value_counts()

# %%
srdf['Country']
# Out:
# 0                United Kingdom
# 1        Bosnia and Herzegovina
# 2                      Thailand
# 3                 United States
# 4                       Ukraine
#                   ...
# 88878                    Canada
# 88879                       NaN
# 88880                       NaN
# 88881                       NaN
# 88882                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
country_respondents
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# ## Total number of people who know Python from each country

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_Python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)

# is sort=False necessary?

# %%
python_df
# Out:
#                    count  LanguageWorkedWith
# Country
# United States      20949               10083
# India               9061                3105
# Germany             5866                2451
# United Kingdom      5737                2384
# Canada              3395                1558
# ...                  ...                 ...
# Tonga                  1                   0
# Timor-Leste            1                   1
# North Korea            1                   0
# Brunei Darussalam      1                   0
# Chad                   1                   0
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'count': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                    NumRespondents  NumKnowsPython
# Country
# United States               20949           10083
# India                        9061            3105
# Germany                      5866            2451
# United Kingdom               5737            2384
# Canada                       3395            1558
# ...                           ...             ...
# Tonga                           1               0
# Timor-Leste                     1               1
# North Korea                     1               0
# Brunei Darussalam               1               0
# Chad                            1               0
#
# [179 rows x 2 columns]

# %%
python_df['% Knows Python'] = 100 * python_df['NumKnowsPython'] / python_df['NumRespondents']

# %%
python_df
# Out:
#                    NumRespondents  NumKnowsPython  % Knows Python
# Country
# United States               20949           10083       48.131176
# India                        9061            3105       34.267741
# Germany                      5866            2451       41.783157
# United Kingdom               5737            2384       41.554820
# Canada                       3395            1558       45.891016
# ...                           ...             ...             ...
# Tonga                           1               0        0.000000
# Timor-Leste                     1               1      100.000000
# North Korea                     1               0        0.000000
# Brunei Darussalam               1               0        0.000000
# Chad                            1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='% Knows Python', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Country
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Dominica                                       1               1
# Niger                                          1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Guinea                                         3               2
# Bahamas                                        3               2
# Guyana                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Haiti                                          5               3
# Benin                                          5               3
# ...

# %%
python_df.loc['Japan', ['NumRespondents', '% Knows Python']]
# Out:
# NumRespondents    391.000000
# % Knows Python     46.547315
# Name: Japan, dtype: float64

# %% [markdown]
# ## Just messing around

# %%
srdf.loc[:, ['Country', 'LanguageWorkedWith']]
# Out:
#                       Country  \
# 0              United Kingdom
# 1      Bosnia and Herzegovina
# 2                    Thailand
# 3               United States
# 4                     Ukraine
# ...                       ...
# 88878                  Canada
# 88879                     NaN
# 88880                     NaN
# 88881                     NaN
# 88882                   Spain
#
#                                       LanguageWorkedWith
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 2                                               HTML/CSS
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...                                                  ...
# 88878                      HTML/CSS;JavaScript;Other(s):
# 88879                                                NaN
# 88880                                                NaN
# ...

# %%
language_filter = srdf['LanguageWorkedWith'].apply(lambda x: 'Python' in str(x))

# %%
srdf[language_filter].loc[:, ['Country', 'LanguageWorkedWith']]
# Out:
#                       Country  \
# 0              United Kingdom
# 1      Bosnia and Herzegovina
# 3               United States
# 4                     Ukraine
# 7                       India
# ...                       ...
# 88854          United Kingdom
# 88860                  Brazil
# 88865             Switzerland
# 88872          Czech Republic
# 88876                   Spain
#
#                                       LanguageWorkedWith
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                  ...
# 88854  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860    Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865    Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# ...

# %%
srdf['Country'].value_counts()
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %% [markdown]
# # Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
import numpy as np

# %%
people = {'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
           'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
          'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@gmail.com', 'JohnDoe@gmail.com', None, np.nan, 'Anonymous@gmail.com', 'NA'],
            'age': ['33', '55', '63', '36', None, None, 'Missing']}

# %%
df3 = pd.DataFrame(people)

# %%
df3
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
# dropna()

# drop row if there is a NaN

# %%
df3.dropna()
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='index', how='any')

# will drop the ROW if ANY of the values are missing, (None, np.nan, (NaN))
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='index', how='all')

# will drop the ROW if ALL values in a row is missing, (None, np.nan, (NaN))
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='columns', how='all')

# drop the COLUMN if ALL values are missing
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='columns', how='any')

# drop the COLUMN if ANY of the data is missing
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df3.dropna(axis='index', how='any', subset=['email'])

# will look at EMAIL column for missing values
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df3.dropna(axis='index', how='all', subset=['last', 'age'])
# Out:
#    first     last                    email      age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JohnDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 6     NA  Missing                       NA  Missing

# %%
df3.replace('NA', np.nan, inplace=True)
df3.replace('Missing', np.nan, inplace=True)

# %%
df3
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@gmail.com    55
# 2   John      Doe        JohnDoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@gmail.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df3.dropna()
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@gmail.com  55
# 2   John      Doe        JohnDoe@gmail.com  63

# %%
df3.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                    email   age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@gmail.com    55
# 2   John      Doe        JohnDoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@gmail.com  None

# %%
df3.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df3.fillna(0)
# Out:
#    first     last                    email age
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@gmail.com  55
# 2   John      Doe        JohnDoe@gmail.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@gmail.com   0
# 6      0        0                        0   0

# %%
df3.fillna('MISSING')
# Out:
#      first     last                    email      age
# 0    Corey  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@gmail.com       55
# 2     John      Doe        JohnDoe@gmail.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@gmail.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df3.dtypes
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
df['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\users\bayram\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1159], line 1
# ----> 1 df['age'].mean()
#
# ...

# %%
type(np.nan)
# Out:
# float

# %%
# df3['age'] = df3['age'].astype(int)

df3['age'] = df3['age'].astype(float)

# %%
df3.dtypes
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df3['age'].mean()
# Out:
# 46.75

# %%
na_vals = ['NA', 'Missing']

# %%
survey_results_df= pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col='Respondent', na_values=na_vals)

# %%
survey_results_df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
survey_results_df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1188], line 1
# ----> 1 survey_results_df['YearsCode'].mean()
#
# File c:\users\bayram\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\users\bayram\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
# ...

# %%
survey_results_df['YearsCode'] = survey_results_df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1189], line 1
# ----> 1 survey_results_df['YearsCode'] = survey_results_df['YearsCode'].astype(float)
#
# File c:\users\bayram\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:6640, in NDFrame.astype(self, dtype, copy, errors)
#    6634     results = [
#    6635         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6636     ]
#    6638 else:
#    6639     # else, only a single dtype is given
# -> 6640     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6641     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6642     return res.__finalize__(self, method="astype")
#
# ...

# %%
survey_results_df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
survey_results_df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
survey_results_df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
survey_results_df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
survey_results_df['YearsCode'] = survey_results_df['YearsCode'].astype(float)

# %%
survey_results_df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
survey_results_df['YearsCode'].median()
# Out:
# 9.0

# %% [markdown]
# # Working with Dates and Time Series Data

# %%
import pandas as pd

# df4 = pd.read_csv('C:/Users/Bayram/Desktop/Cewka Python/ETH_1h.csv')

# Ethereum  , 1 hour segments

from datetime import datetime

d_parser = lambda x: datetime.strptime(x, "%Y-%m-%d %I-%p")

df4 = pd.read_csv('C:/Users/Bayram/Desktop/Cewka Python/files/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)

# direct conversion while parsing ,BRUUUUUH
# Out:
# C:\Users\Bayram\AppData\Local\Temp\ipykernel_12528\681588671.py:11: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   df4 = pd.read_csv('C:/Users/Bayram/Desktop/Cewka Python/files/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)

# %%
df4.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df4.shape
# Out:
# (23674, 7)

# %%
df4['Date']
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df4.loc[0, 'Date'].day_name()

# in this case, it is string
# Out:
# 'Friday'

# %%
# df4['Date'] = pd.to_datetime(df4['Date'])

# It can be done directly while parsing

# %%
# df4['Date'] = pd.to_datetime(df4['Date'], format='%Y-%m-%d %I-%p')

# It can be done directly while parsing.

# %%
# df4.loc[0, 'Date'].day_name()

# %%
df4['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df4['Day'] = df4['Date'].dt.day_name()

# %%
df4
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#             Day
# ...

# %%
df4['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df4['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df4['Date'].max() - df4['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt10 = (df4['Date'] >= '2019') & (df4['Date'] < '2020')
df4.loc[filt10]

# those two are the same

filt10_1 = (df4['Date'] >= pd.to_datetime('2019-01-01')) & (df4['Date'] < pd.to_datetime('2020-01-01'))
df4.loc[filt10_1]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#            Day
# 1749   Tuesday
# ...

# %%
df4.set_index('Date')
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                           Day
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df4.set_index('Date', inplace=True)

# %%
df4
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                           Day
# Date
# 2020-03-13 20:00:00    Friday
# ...

# %%
df4.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                          Day
# Date
# 2019-12-31 23:00:00  Tuesday
# 2019-12-31 22:00:00  Tuesday
# ...

# %%
# df4.loc['2019-01-01 00:00:00':'2020-01-01 00:00:00']
# will give an error. Define a and b and set them to required date values
a = pd.to_datetime('2020-02-29 23:00:00')
b = pd.to_datetime('2020-01')
df4.loc[a:b]
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                            Day
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
df4.loc[a:b]['Close']
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
df4.loc[a:b]['Close'].mean()
# Out:
# 195.1655902777778

# %%
df4.loc[a:b].head(24)
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# 2020-02-29 18:00:00  ETHUSD  225.53  226.17  224.50  225.09   496543.91
# 2020-02-29 17:00:00  ETHUSD  222.68  225.53  222.24  225.53   611136.47
# 2020-02-29 16:00:00  ETHUSD  224.17  225.93  222.36  222.68   694384.75
# 2020-02-29 15:00:00  ETHUSD  223.35  225.88  221.80  224.17   550893.74
# 2020-02-29 14:00:00  ETHUSD  224.42  224.42  221.15  223.35  1479928.44
# 2020-02-29 13:00:00  ETHUSD  225.29  225.37  222.87  224.42  1076646.41
# 2020-02-29 12:00:00  ETHUSD  226.50  226.50  224.14  225.29   359022.09
# ...

# %%
df4.loc['2020-01-01']['High']
# Out:
# Date
# 2020-01-01 23:00:00    130.27
# 2020-01-01 22:00:00    131.41
# 2020-01-01 21:00:00    131.99
# 2020-01-01 20:00:00    131.87
# 2020-01-01 19:00:00    131.72
# 2020-01-01 18:00:00    132.14
# 2020-01-01 17:00:00    132.68
# 2020-01-01 16:00:00    132.56
# 2020-01-01 15:00:00    132.15
# 2020-01-01 14:00:00    132.05
# 2020-01-01 13:00:00    132.08
# 2020-01-01 12:00:00    131.31
# 2020-01-01 11:00:00    131.42
# 2020-01-01 10:00:00    130.33
# 2020-01-01 09:00:00    130.22
# 2020-01-01 08:00:00    130.01
# 2020-01-01 07:00:00    130.25
# 2020-01-01 06:00:00    130.25
# 2020-01-01 05:00:00    129.94
# 2020-01-01 04:00:00    130.00
# 2020-01-01 03:00:00    130.44
# 2020-01-01 02:00:00    130.50
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.54
# Name: High, dtype: float64

# %%
df4.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
highs = df4['High'].resample('D').max()

highs
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

# %%
highs.plot(title='Highs', ylabel='ETH')
# Out:
# <Axes: title={'center': 'Highs'}, xlabel='Date', ylabel='ETH'>

# %%
df4.resample('W').mean(numeric_only=True)

# numeric_only=True  is old behaviour and you will not get an error
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
df4.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume':'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]

# %% [markdown]
# # Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc.

# %% [markdown]
# `.loc`    `90ZB824`
# *just*   **messing**  around
# > what is this

# %%
# pip install jupyter-ai

# installed. Will probably use it later

5
# Out:
# 5

# %%
survey_results_df = pd.read_csv('C:/Users/Bayram/Downloads/stack-overflow-developer-survey-2019/survey_results_public.csv', index_col='Respondent')

pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 20)

survey_results_df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt_ = (survey_results_df['Country'] == 'India')

India_df = survey_results_df[filt_]

India_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
India_df.to_csv('modified.csv')

# %%
India_df.to_csv('modified.tsv', sep='\t')

# csv - Comma Separated Values
# tsv - Tab Separated Values

# %%
India_df.to_excel('modified.xlsx')

# %%
test = pd.read_excel('C:/Users/Bayram/Desktop/Cewka Python/modified.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
India_df.to_json('modified.json')

# %%
India_df.to_json('modified.json', orient='records', lines=True)

# %%
test1 = pd.read_json('modified.json', orient='records', lines=True)

test1.head()
# Out:
#                                MainBranch Hobbyist  \
# 0             I code primarily as a hobby      Yes
# 1          I am a developer by profession      Yes
# 2  I am a student who is learning to code      Yes
# 3          I am a developer by profession      Yes
# 4          I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0     Less than once per year
# 1  Once a month or more often
# 2                       Never
# 3  Once a month or more often
# 4                       Never
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of HIGHER quality than pro...
# 2  OSS is, on average, of HIGHER quality than pro...
# 3  OSS is, on average, of LOWER quality than prop...
# 4                                               None
#
#                            Employment Country         Student  \
# 0  Not employed, but looking for work   India            None
# ...

# %%
# SQL, but I don't know it YET.

# %%
# from urllib.request import urlretrieve
# urlretrieve('https://github.com/CoreyMSchafer/code_snippets/blob/master/Python/Flask_Blog/snippets/posts.json', 'posts.json')

# # posts_df = pd.read_json('posts.json', orient='records', lines=True)

# import json
# with open('posts.json') as datafile:
#     data = json.load(datafile)
# retail = pd.DataFrame(data)

# some thaaaaaangs happened here. Probably not my problem.
