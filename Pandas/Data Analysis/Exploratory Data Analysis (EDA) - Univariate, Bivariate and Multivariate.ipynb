# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Bayram/Downloads/supermarket_sales - Sheet1.csv', parse_dates=['Date'])

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.sample(5)
# Out:
#       Invoice ID Branch      City Customer type  Gender  \
# 603  642-30-6693      B  Mandalay        Normal  Female
# 685  241-96-5076      B  Mandalay        Member  Female
# 670  588-47-8641      A    Yangon        Member    Male
# 360  612-36-5536      A    Yangon        Member    Male
# 505  726-29-6793      A    Yangon        Member    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 603       Sports and travel       54.51         6  16.353  343.413  3/17/2019
# 685      Home and lifestyle       49.10         2   4.910  103.110   1/8/2019
# 670     Fashion accessories       56.04        10  28.020  588.420  1/14/2019
# 360      Food and beverages       80.96         8  32.384  680.064  2/17/2019
# 505  Electronic accessories       24.18         8   9.672  203.112  1/28/2019
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# 603  13:54      Ewallet  327.06                 4.761905        16.353     7.8
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
cate=[]
num=[]
for column in df.columns:
    if df[column].nunique() > 10:
        num.append(column)
    else:
        cate.append(column)

print(cate, 3*'\n', num)
# Out:
# ['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Quantity', 'Payment', 'gross margin percentage']
#
#
#  ['Invoice ID', 'Unit price', 'Tax 5%', 'Total', 'Date', 'Time', 'cogs', 'gross income', 'Rating']

# %%
sns.countplot(data=df,
             x='Branch')
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
df['Branch'].value_counts().plot(kind='pie', autopct='%1.2f%%')
plt.show()

# %%
df['Branch'].value_counts().plot(kind='bar')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Payment'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Ewallet'), Text(1, 0, 'Cash'), Text(2, 0, 'Credit card')])

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
# plt.figure(figsize=(15,10))
sns.displot(data=df,
           x='Rating',
           kind='kde')

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
sns.displot(data=df,
            x='cogs',
           kind='kde',
           aspect=1.5,)

# %%
df['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(data=df,
           x='cogs')
# Out:
# <Axes: xlabel='cogs'>

# %%
sns.scatterplot(data=df, 
               x='cogs',
               y='Rating')
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
sns.scatterplot(data=df,
               x='gross income',
               y='Rating')
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(data=df,
           y='gross income',
           x='Branch')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
df.loc[:, ['gross income', 'Branch']].groupby('Branch')[ 'gross income'].mean()
# Out:
# Branch
# A    14.874001
# B    15.232024
# C    16.052367
# Name: gross income, dtype: float64

# %%
sns.barplot(data=df,
           y='gross income',
           x='Branch',
           hue='City')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.boxplot(data=df,
           y='Gender',
           x='gross income')
# Out:
# <Axes: xlabel='gross income', ylabel='Gender'>

# %%
sns.boxplot(data=df,
           y='Gender',
           x='gross income',
           hue='Customer type')
# Out:
# <Axes: xlabel='gross income', ylabel='Gender'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(data=df,
           x='Product line',
           y='gross income')
plt.xticks(rotation=60)
plt.show()

# %%
df.groupby('Product line')['gross income'].mean().sort_values(ascending=False)
# Out:
# Product line
# Home and lifestyle        16.030331
# Sports and travel         15.812630
# Health and beauty         15.411572
# Food and beverages        15.365310
# Electronic accessories    15.220597
# Fashion accessories       14.528062
# Name: gross income, dtype: float64

# %%
sns.barplot(data=df,
           x='Product line',
           y='Unit price')
plt.xticks(rotation=60)
plt.show()

# %%
df.loc[:, ['Product line', 'Unit price']].groupby('Product line')['Unit price'].mean().sort_values(ascending=False)
# Out:
# Product line
# Fashion accessories       57.153652
# Sports and travel         56.993253
# Food and beverages        56.008851
# Home and lifestyle        55.316937
# Health and beauty         54.854474
# Electronic accessories    53.551588
# Name: Unit price, dtype: float64

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
pd.crosstab(index=df['City'], columns=df['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(index=df['City'], columns=df['Payment']), annot=True)
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df \
.loc[:, ['Product line', 'Quantity']] \
.groupby('Product line')['Quantity'].sum()


# I can see the content before groupby


# or
# df.groupby('Product line')['Quantity'].sum()
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64

# %%
df \
.loc[:, ['Product line', 'Quantity']] \
.groupby('Product line')['Quantity'].sum() \
.plot(kind='bar')

plt.xticks(rotation=60)
plt.show()

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date'].dt.dayofweek
# Out:
# 0      5
# 1      4
# 2      6
# 3      6
# 4      4
#       ..
# 995    1
# 996    5
# 997    5
# 998    4
# 999    0
# Name: Date, Length: 1000, dtype: int32

# %%
df['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
dw_mapping = {
    0:'Mon',
    1:'Tue',
    2:'Wed',
    3:'Thu',
    4:'Fri',
    5:'Sat',
    6:'Sun'
}

# %%
df['Date'].dt.dayofweek.map(dw_mapping)
# Out:
# 0      Sat
# 1      Fri
# 2      Sun
# 3      Sun
# 4      Fri
#       ...
# 995    Tue
# 996    Sat
# 997    Sat
# 998    Fri
# 999    Mon
# Name: Date, Length: 1000, dtype: object

# %%
df['Day of Week'] = df['Date'].dt.dayofweek.map(dw_mapping)

# %%
df['Day of Week'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %%
sns.barplot(data=df['Day of Week'].value_counts())
# Out:
# <Axes: xlabel='Day of Week', ylabel='count'>

# %%
df['Month'] = df['Date'].dt.month.map({
    1:'Jan',
    2:'Feb',
    3:'Mar',
    4:'Apr',
    5:'May',
    6:'Jun',
    7:'Jul',
    8:'Aug',
    9:'Sep',
    10:'Oct',
    11:'Nov',
    12:'Dec'
})
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df['Month'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, 'Jan'), Text(1, 0, 'Mar'), Text(2, 0, 'Feb')])
