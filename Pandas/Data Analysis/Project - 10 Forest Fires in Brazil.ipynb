# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Bayram/Downloads/amazon.csv', encoding='iso-8859-1', parse_dates=['date'])
df
# Out:
#       year      state     month  number       date
# 0     1998       Acre   Janeiro     0.0 1998-01-01
# 1     1999       Acre   Janeiro     0.0 1999-01-01
# 2     2000       Acre   Janeiro     0.0 2000-01-01
# 3     2001       Acre   Janeiro     0.0 2001-01-01
# 4     2002       Acre   Janeiro     0.0 2002-01-01
# ...    ...        ...       ...     ...        ...
# 6449  2012  Tocantins  Dezembro   128.0 2012-01-01
# 6450  2013  Tocantins  Dezembro    85.0 2013-01-01
# 6451  2014  Tocantins  Dezembro   223.0 2014-01-01
# 6452  2015  Tocantins  Dezembro   373.0 2015-01-01
# 6453  2016  Tocantins  Dezembro   119.0 2016-01-01
#
# [6454 rows x 5 columns]

# %%
df.dtypes
# Out:
# year               int64
# state             object
# month             object
# number           float64
# date      datetime64[ns]
# dtype: object

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
df.head(2)
# Out:
#    year state    month  number       date
# 0  1998  Acre  Janeiro     0.0 1998-01-01
# 1  1999  Acre  Janeiro     0.0 1999-01-01

# %%
df.tail(2)
# Out:
#       year      state     month  number       date
# 6452  2015  Tocantins  Dezembro   373.0 2015-01-01
# 6453  2016  Tocantins  Dezembro   119.0 2016-01-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 252.2+ KB

# %%
df.describe()
# Out:
#               year       number                           date
# count  6454.000000  6454.000000                           6454
# mean   2007.461729   108.293163  2007-06-18 18:28:53.622559488
# min    1998.000000     0.000000            1998-01-01 00:00:00
# 25%    2002.000000     3.000000            2002-01-01 00:00:00
# 50%    2007.000000    24.000000            2007-01-01 00:00:00
# 75%    2012.000000   113.000000            2012-01-01 00:00:00
# max    2017.000000   998.000000            2017-01-01 00:00:00
# std       5.746654   190.812242                            NaN

# %%
df.shape
# Out:
# (6454, 5)

# %%
df.duplicated().any()
# Out:
# True

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (6422, 5)

# %%
df.isnull()
# Out:
#        year  state  month  number   date
# 0     False  False  False   False  False
# 1     False  False  False   False  False
# 2     False  False  False   False  False
# 3     False  False  False   False  False
# 4     False  False  False   False  False
# ...     ...    ...    ...     ...    ...
# 6449  False  False  False   False  False
# 6450  False  False  False   False  False
# 6451  False  False  False   False  False
# 6452  False  False  False   False  False
# 6453  False  False  False   False  False
#
# [6422 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# year      0
# state     0
# month     0
# number    0
# date      0
# dtype: int64

# %%
df.describe(include=[np.number])
# Out:
#               year       number
# count  6422.000000  6422.000000
# mean   2007.490969   108.815178
# std       5.731806   191.142482
# min    1998.000000     0.000000
# 25%    2003.000000     3.000000
# 50%    2007.000000    24.497000
# 75%    2012.000000   114.000000
# max    2017.000000   998.000000

# %%
df.describe(include='all')
# Out:
#                year state   month       number                           date
# count   6422.000000  6422    6422  6422.000000                           6422
# unique          NaN    23      12          NaN                            NaN
# top             NaN   Rio  Agosto          NaN                            NaN
# freq            NaN   697     540          NaN                            NaN
# mean    2007.490969   NaN     NaN   108.815178  2007-06-29 10:46:40.622859008
# min     1998.000000   NaN     NaN     0.000000            1998-01-01 00:00:00
# 25%     2003.000000   NaN     NaN     3.000000            2003-01-01 00:00:00
# 50%     2007.000000   NaN     NaN    24.497000            2007-01-01 00:00:00
# 75%     2012.000000   NaN     NaN   114.000000            2012-01-01 00:00:00
# max     2017.000000   NaN     NaN   998.000000            2017-01-01 00:00:00
# std        5.731806   NaN     NaN   191.142482                            NaN

# %%
df.head()
# Out:
#    year state    month  number       date
# 0  1998  Acre  Janeiro     0.0 1998-01-01
# 1  1999  Acre  Janeiro     0.0 1999-01-01
# 2  2000  Acre  Janeiro     0.0 2000-01-01
# 3  2001  Acre  Janeiro     0.0 2001-01-01
# 4  2002  Acre  Janeiro     0.0 2002-01-01

# %%
df['Month'] = df['month'].map({'Janeiro': 'January',
                              'Fevereiro': 'February',
                              'Março': 'March',
                              'Abril': 'April',
                              'Maio': 'May',
                              'Junho': 'June',
                              'Julho': 'July',
                              'Agosto': 'August',
                               'Setembro': 'September',
                               'Outubro': 'October',
                               'Novembro': 'November',
                               'Dezembro': 'December'
                              })

# %%
df
# Out:
#       year      state     month  number       date     Month
# 0     1998       Acre   Janeiro     0.0 1998-01-01   January
# 1     1999       Acre   Janeiro     0.0 1999-01-01   January
# 2     2000       Acre   Janeiro     0.0 2000-01-01   January
# 3     2001       Acre   Janeiro     0.0 2001-01-01   January
# 4     2002       Acre   Janeiro     0.0 2002-01-01   January
# ...    ...        ...       ...     ...        ...       ...
# 6449  2012  Tocantins  Dezembro   128.0 2012-01-01  December
# 6450  2013  Tocantins  Dezembro    85.0 2013-01-01  December
# 6451  2014  Tocantins  Dezembro   223.0 2014-01-01  December
# 6452  2015  Tocantins  Dezembro   373.0 2015-01-01  December
# 6453  2016  Tocantins  Dezembro   119.0 2016-01-01  December
#
# [6422 rows x 6 columns]

# %%
df.drop(axis=1, columns=['month'], inplace=True)

# %%
df.shape
# Out:
# (6422, 5)

# %%
df.columns
# Out:
# Index(['year', 'state', 'number', 'date', 'Month'], dtype='object')

# %%
df.loc[:, ['Month', 'number']].sort_values(by='number', ascending=False).max()
# Out:
# Month     September
# number        998.0
# dtype: object

# %%
(df.groupby('Month')['number'].sum()).max()
# Out:
# 92319.113

# %%
df.groupby('Month')['number'].sum()
# Out:
# Month
# April        28184.770
# August       88050.435
# December     57535.480
# February     30839.050
# January      47681.844
# July         92319.113
# June         55997.675
# March        30709.405
# May          34725.363
# November     85508.054
# October      88681.579
# September    58578.305
# Name: number, dtype: float64

# %%
df.groupby('Month')['number'].sum().sort_values(ascending=False)
# Out:
# Month
# July         92319.113
# October      88681.579
# August       88050.435
# November     85508.054
# September    58578.305
# December     57535.480
# June         55997.675
# January      47681.844
# May          34725.363
# February     30839.050
# March        30709.405
# April        28184.770
# Name: number, dtype: float64

# %%
df.groupby('Month')['number'].sum().reset_index()
# Out:
#         Month     number
# 0       April  28184.770
# 1      August  88050.435
# 2    December  57535.480
# 3    February  30839.050
# 4     January  47681.844
# 5        July  92319.113
# 6        June  55997.675
# 7       March  30709.405
# 8         May  34725.363
# 9    November  85508.054
# 10    October  88681.579
# 11  September  58578.305

# %%
number_of_reported_fires_per_month = df.groupby('Month')['number'].sum().reset_index().sort_values(by='number', ascending=False)
number_of_reported_fires_per_month
# Out:
#         Month     number
# 5        July  92319.113
# 10    October  88681.579
# 1      August  88050.435
# 9    November  85508.054
# 11  September  58578.305
# 2    December  57535.480
# 6        June  55997.675
# 4     January  47681.844
# 8         May  34725.363
# 3    February  30839.050
# 7       March  30709.405
# 0       April  28184.770

# %%
sns.barplot(x=number_of_reported_fires_per_month['number'],
           y=number_of_reported_fires_per_month['Month'])
# Out:
# <Axes: xlabel='number', ylabel='Month'>

# %%
plt.figure(figsize=(16,5))
sns.barplot(y=number_of_reported_fires_per_month['number'],
           x=number_of_reported_fires_per_month['Month'])
# Out:
# <Axes: xlabel='Month', ylabel='number'>

# %%
df.columns
# Out:
# Index(['year', 'state', 'number', 'date', 'Month'], dtype='object')

# %%
df.groupby('year')['number'].sum()
# Out:
# year
# 1998    20013.971
# 1999    26882.821
# 2000    27351.251
# 2001    29054.612
# 2002    37390.600
# 2003    42760.674
# 2004    38450.163
# 2005    35004.965
# 2006    33824.161
# 2007    33028.413
# 2008    29378.964
# 2009    39116.178
# 2010    37037.449
# 2011    34633.545
# 2012    40084.860
# 2013    35137.118
# 2014    39621.183
# 2015    41208.292
# 2016    42212.229
# 2017    36619.624
# Name: number, dtype: float64

# %%
number_of_reported_fires_per_year = df.groupby('year')['number'].sum().sort_values(ascending=False).reset_index()
number_of_reported_fires_per_year
# Out:
#     year     number
# 0   2003  42760.674
# 1   2016  42212.229
# 2   2015  41208.292
# 3   2012  40084.860
# 4   2014  39621.183
# 5   2009  39116.178
# 6   2004  38450.163
# 7   2002  37390.600
# 8   2010  37037.449
# 9   2017  36619.624
# 10  2013  35137.118
# 11  2005  35004.965
# 12  2011  34633.545
# 13  2006  33824.161
# 14  2007  33028.413
# 15  2008  29378.964
# 16  2001  29054.612
# 17  2000  27351.251
# 18  1999  26882.821
# 19  1998  20013.971

# %%
plt.figure(figsize=(16,5))
sns.barplot(y=number_of_reported_fires_per_year['number'],
           x=number_of_reported_fires_per_year['year'])
# Out:
# <Axes: xlabel='year', ylabel='number'>

# %%
df.columns
# Out:
# Index(['year', 'state', 'number', 'date', 'Month'], dtype='object')

# %%
number_of_reported_fires_per_state = df.groupby('state')['number'].sum().reset_index().sort_values(by='number', ascending=False)
number_of_reported_fires_per_state
# Out:
#                state     number
# 10       Mato Grosso  96246.028
# 12           Paraiba  52426.918
# 20         Sao Paulo  51121.198
# 16               Rio  45094.865
# 4              Bahia  44746.226
# 15              Piau  37803.747
# 8              Goias  37695.520
# 11      Minas Gerais  37475.258
# 22         Tocantins  33707.885
# 3           Amazonas  30650.129
# 5              Ceara  30428.063
# 9           Maranhao  25129.131
# 13              Pará  24512.144
# 14        Pernambuco  24498.000
# 18           Roraima  24385.074
# 19    Santa Catarina  24359.852
# 2              Amapa  21831.576
# 17          Rondonia  20285.429
# 0               Acre  18464.030
# 7     Espirito Santo   6546.000
# 1            Alagoas   4606.000
# 6   Distrito Federal   3561.000
# 21           Sergipe   3237.000

# %%
plt.figure(figsize=(16,5))
sns.barplot(x=number_of_reported_fires_per_state['state'],
           y=number_of_reported_fires_per_state['number'])
plt.xticks(rotation=75)
plt.show()

# %%
df[df['state']=='Amazonas']
# Out:
#      year     state  number       date     Month
# 718  1998  Amazonas     0.0 1998-01-01   January
# 719  1999  Amazonas     3.0 1999-01-01   January
# 720  2000  Amazonas     7.0 2000-01-01   January
# 721  2001  Amazonas     3.0 2001-01-01   January
# 722  2002  Amazonas    17.0 2002-01-01   January
# ..    ...       ...     ...        ...       ...
# 952  2012  Amazonas    80.0 2012-01-01  December
# 953  2013  Amazonas   236.0 2013-01-01  December
# 954  2014  Amazonas   293.0 2014-01-01  December
# 955  2015  Amazonas   565.0 2015-01-01  December
# 956  2016  Amazonas   133.0 2016-01-01  December
#
# [239 rows x 5 columns]

# %%
df.groupby('state')['number'].sum()
# Out:
# state
# Acre                18464.030
# Alagoas              4606.000
# Amapa               21831.576
# Amazonas            30650.129
# Bahia               44746.226
# Ceara               30428.063
# Distrito Federal     3561.000
# Espirito Santo       6546.000
# Goias               37695.520
# Maranhao            25129.131
# Mato Grosso         96246.028
# Minas Gerais        37475.258
# Paraiba             52426.918
# Pará                24512.144
# Pernambuco          24498.000
# Piau                37803.747
# Rio                 45094.865
# Rondonia            20285.429
# Roraima             24385.074
# Santa Catarina      24359.852
# Sao Paulo           51121.198
# Sergipe              3237.000
# Tocantins           33707.885
# Name: number, dtype: float64

# %%
df['state'] == 'Amazonas'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6449    False
# 6450    False
# 6451    False
# 6452    False
# 6453    False
# Name: state, Length: 6422, dtype: bool

# %%
df[df['state'] == 'Amazonas'].loc[:, ['state', 'number']].sum()
# Out:
# state     AmazonasAmazonasAmazonasAmazonasAmazonasAmazon...
# number                                            30650.129
# dtype: object

# %%
df[df['state'] == 'Amazonas']['number'].sum()
# Out:
# 30650.129

# %%
year_wise_reported_fires_in_amazonas = df[df['state'] == 'Amazonas'].groupby('year')['number'].sum().reset_index().sort_values(by='number', ascending=False)
year_wise_reported_fires_in_amazonas
# Out:
#     year    number
# 4   2002  2852.000
# 10  2008  2717.000
# 16  2014  2385.909
# 12  2010  2324.508
# 6   2004  2298.207
# 18  2016  2060.972
# 7   2005  1657.128
# 13  2011  1652.538
# 5   2003  1524.268
# 11  2009  1320.601
# 3   2001  1297.000
# 17  2015  1189.994
# 14  2012  1110.641
# 1   1999  1061.000
# 8   2006   997.640
# 0   1998   946.000
# 19  2017   906.905
# 15  2013   905.217
# 2   2000   853.000
# 9   2007   589.601

# %%
plt.figure(figsize=(16,5))
sns.barplot(data=year_wise_reported_fires_in_amazonas,
           x=year_wise_reported_fires_in_amazonas['year'],
           y=year_wise_reported_fires_in_amazonas['number'])
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['year', 'state', 'number', 'date', 'Month'], dtype='object')

# %%
state_Amazonas = df[df['state'] == 'Amazonas']
state_Amazonas
# Out:
#      year     state  number       date     Month
# 718  1998  Amazonas     0.0 1998-01-01   January
# 719  1999  Amazonas     3.0 1999-01-01   January
# 720  2000  Amazonas     7.0 2000-01-01   January
# 721  2001  Amazonas     3.0 2001-01-01   January
# 722  2002  Amazonas    17.0 2002-01-01   January
# ..    ...       ...     ...        ...       ...
# 952  2012  Amazonas    80.0 2012-01-01  December
# 953  2013  Amazonas   236.0 2013-01-01  December
# 954  2014  Amazonas   293.0 2014-01-01  December
# 955  2015  Amazonas   565.0 2015-01-01  December
# 956  2016  Amazonas   133.0 2016-01-01  December
#
# [239 rows x 5 columns]

# %%
day = state_Amazonas.groupby(state_Amazonas['date'].dt.dayofweek).sum(numeric_only=True).number
# no bruh


import calendar
day.index = [calendar.day_name[x] for x in range(0,7)]
day = day.reset_index()

# %%
day
# Out:
#        index    number
# 0     Monday  1886.601
# 1    Tuesday  6474.217
# 2  Wednesday  3910.177
# 3   Thursday  5754.802
# 4     Friday  5446.480
# 5   Saturday  4162.666
# 6     Sunday  3015.186

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=day,
           y=day['number'],
           x=day['index'])
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['year', 'state', 'number', 'date', 'Month'], dtype='object')

# %%
df[df['year'] == 2015]['number'].sum()
# Out:
# 41208.292

# %%
monthly_reports_in_2015 = df[df['year'] == 2015].groupby('Month')['number'].sum().reset_index() \
#.sort_values(by='number', ascending=False)
monthly_reports_in_2015
# Out:
#         Month    number
# 0       April  2573.000
# 1      August  4363.125
# 2    December  4088.522
# 3    February  2309.000
# 4     January  4635.000
# 5        July  4364.392
# 6        June  3260.552
# 7       March  2202.000
# 8         May  2384.000
# 9    November  4034.518
# 10    October  4499.525
# 11  September  2494.658

# %%
plt.figure(figsize=(12,5))
sns.barplot(data=monthly_reports_in_2015,
           x=monthly_reports_in_2015['Month'],
           y=monthly_reports_in_2015['number'])
plt.xticks(rotation=30)
plt.show()

# %%
# %%timeit

plt.figure(figsize=(12,5))
sns.barplot(data=df.groupby('state')['number'].mean().sort_values(ascending=False))
plt.xticks(rotation=75)
plt.show()

# in one go
# Out:
# 753 ms ± 30.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
df.columns
# Out:
# Index(['year', 'state', 'number', 'date', 'Month'], dtype='object')

# %%
df[df['Month'] == 'December']['state'].unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Minas Gerais', 'Pará', 'Paraiba', 'Pernambuco',
#        'Piau', 'Rio', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins'], dtype=object)
